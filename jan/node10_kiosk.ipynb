# %% [markdown]
# # node 10 프로젝트:내가 만든 키오스크 01

# %%
from Kiosk_test import Kiosk

# %% [markdown]
# ## Kiosk 2

# %% [markdown]
# #### 지불

# %%
def pay(self):
    # print(f"총 결제 금액은 {sum(self.order_price)}원 입니다.")

    while True:
        # 입력을 문자열로 받아서 처리 (또는 int로 받아서 처리)

        user_input = input("현금(1) 또는 카드(2)를 선택하세요 : ")

        if user_input == '1' or user_input == 'cash':
            print("직원을 호출하겠습니다.")
            break
        elif user_input == '2' or user_input == 'card':
            print("IC칩 방향에 맞게 카드를 꽂아주세요.")
            break
        else:
            print("다시 결제를 시도해 주세요.")

# %%
# kiosk = Kiosk()
# kiosk.menu_select()
# Out:
# 1 americano  :  2000 원
# 2 latte  :  3000 원
# 3 mocha  :  3000 원
# 4 yuza_tea  :  2500 원
# 5 green_tea  :  2500 원
# 6 choco_latte  :  3000 원
#
# 주문 음료 HOT americano  :  2000 원
# ------------------------------
# 1 americano  :  2000 원
# 2 latte  :  3000 원
# 3 mocha  :  3000 원
# 4 yuza_tea  :  2500 원
# 5 green_tea  :  2500 원
# 6 choco_latte  :  3000 원
#
# 주문이 완료되었습니다.
# ...
# << 주문 내역 확인 >>
# 주문 리스트: ['HOT americano']
# 가격 리스트: [2000]
# ...

# %% [markdown]
# ### 아래 셀  코드는 이미정의된클래스(Kiosk)에 나중에메서드를 추가(연결)하는기법 입니다.
# 외부셀: Kiosk 클래스정의(당시에는 pay방법이 없습니다) pay 함수를따로정의(여기서로직을작성)
# 사용셀: Kiosk.pay = pay 런닝(이순간 Kiosk클래스에 pay기능이장착됨)
# 이렇게 하면 이미생성된 환자체에서도 pay()메서드를 호출할 수 있습니다.
# #### 본래의 Kiosk 클래스에는 pay메서드가 없었다 불러와서 사용하려면 에러가 난다
# #### 위의 코드는 Kiosk 클래스에 pay 라는 메서드에 방금위에서 작성한 pay 함수를 넣어줘라
# #### 라는 쥬피터용 문법이다

# %%
Kiosk.pay =pay

# %%
a = Kiosk()  # 객체 생성
a.menu_print()  # 메뉴 출력
a.menu_select()  # 주문
a.pay()  # 지불
# Out:
# 1 americano  :  2000 원
# 2 latte  :  3000 원
# 3 mocha  :  3000 원
# 4 yuza_tea  :  2500 원
# 5 green_tea  :  2500 원
# 6 choco_latte  :  3000 원
#
# 1 americano  :  2000 원
# 2 latte  :  3000 원
# 3 mocha  :  3000 원
# 4 yuza_tea  :  2500 원
# 5 green_tea  :  2500 원
# 6 choco_latte  :  3000 원
#
# 주문 음료 HOT americano  :  2000 원
# ------------------------------
# 1 americano  :  2000 원
# 2 latte  :  3000 원
# 3 mocha  :  3000 원
# 4 yuza_tea  :  2500 원
# 5 green_tea  :  2500 원
# 6 choco_latte  :  3000 원
#
# 주문이 완료되었습니다.
# ...
# << 주문 내역 확인 >>
# 주문 리스트: ['HOT americano']
# 가격 리스트: [2000]
# ...
# 총 결제 금액은 2000원 입니다.
# IC칩 방향에 맞게 카드를 꽂아주세요.

# %% [markdown]
# #### 주문표

# %%
menu_temp = ['HOT americano', 'ICE latte', 'ICE mocha', 'ICE choco_latte']
price_temp = [2000, 3000, 3000, 3000]

# 외곽
print('⟝' + '-' * 30 + '⟞')
for i in range(5):
    print('|' + ' ' * 31 + '|')

# 주문 상품명 : 해당 금액
for i in range(len(menu_temp)):
    print(menu_temp[i], ' : ', price_temp[i])

print('합계 금액 :', sum(price_temp))

# 외곽
for i in range(5):
    print('|' + ' ' * 31+ '|')
print('⟝' + '-' * 30 + '⟞')
# Out:
# ⟝------------------------------⟞
# |                               |
# |                               |
# |                               |
# |                               |
# |                               |
# HOT americano  :  2000
# ICE latte  :  3000
# ICE mocha  :  3000
# ICE choco_latte  :  3000
# 합계 금액 : 11000
# |                               |
# |                               |
# |                               |
# |                               |
# |                               |
# ⟝------------------------------⟞

# %% [markdown]
# ### 수정 주문표

# %%
    # 주문표 출력 메서드
def table(self):
    # 외곽 상단
    print('⟝' + '-' * 30 + '⟞')

     # 상단 여백
    for i in range(5):
        print('|' + ' ' * 30 + '|')  # 공백을 30으로 맞춤 (가독성 조정)

    # 주문 상품명 : 해당 금액 (세로선 추가)
    for i in range(len(self.order_menu)):
        # 좌우에 | 를 붙이고 내용을 배치
         print('| ' + self.order_menu[i] + ' : ' + str(self.order_price[i]) + ' |')

    # 합계 금액 (세로선 추가)
    print('| 합계 금액 :', sum(self.order_price), ' |')

    # 하단 여백
    for i in range(5):
        print('|' + ' ' * 30 + '|')  # 공백을 30으로 맞춤 (가독성 조정)

    # 외곽 하단
    print('⟝' + '-' * 30 + '⟞')

# 실행 테스트
kiosk = Kiosk()
kiosk.menu_select()
# Out:
# 1 americano  :  2000 원
# 2 latte  :  3000 원
# 3 mocha  :  3000 원
# 4 yuza_tea  :  2500 원
# 5 green_tea  :  2500 원
# 6 choco_latte  :  3000 원
#
# 주문 음료 HOT americano  :  2000 원
# ------------------------------
# 1 americano  :  2000 원
# 2 latte  :  3000 원
# 3 mocha  :  3000 원
# 4 yuza_tea  :  2500 원
# 5 green_tea  :  2500 원
# 6 choco_latte  :  3000 원
#
# 주문이 완료되었습니다.
# ...
# << 주문 내역 확인 >>
# 주문 리스트: ['HOT americano']
# 가격 리스트: [2000]
# ...

# %%
from kiosk_final import *

# %%
test=Kiosk()
test.menu
# Out:
# ['americano', 'latte', 'mocha', 'yuza_tea', 'green_tea', 'choco_latte']

# %%
test.price
# Out:
# [2000, 3000, 3000, 2500, 2500, 3000]

# %%
test.menu_print()
# Out:
# 1 americano  :  2000 원
# 2 latte  :  3000 원
# 3 mocha  :  3000 원
# 4 yuza_tea  :  2500 원
# 5 green_tea  :  2500 원
# 6 choco_latte  :  3000 원

# %%
test.menu_select()
# Out:
# americano : 2000 원
# 추가 주문 음료 HOT americano : 2000 원
#
# 추가 주문 음료 HOT latte  :  3000 원
#  합계 :  5000 원
#
# 추가 주문 음료 HOT mocha  :  3000 원
#  합계 :  8000 원
#
# 추가 주문 음료 HOT yuza_tea  :  2500 원
#  합계 :  10500 원
#
# 추가 주문 음료 HOT green_tea  :  2500 원
#  합계 :  13000 원
#
# 추가 주문 음료 HOT choco_latte  :  3000 원
#  합계 :  16000 원
#
# 주문이 완료 되었습니다
# ['HOT latte', 'HOT mocha', 'HOT yuza_tea', 'HOT green_tea', 'HOT choco_latte'] [3000, 3000, 2500, 2500, 3000]

# %%
test.pay()
# Out:
# 총 합계 금액은 16000원 입니다.
# 직원을 호출하겠습니다.

# %%
test.table()
# Out:
# ⟝------------------------------⟞
# |                               |
# |                               |
# |                               |
# |                               |
# |                               |
# HOT latte  :  3000
# HOT mocha  :  3000
# HOT yuza_tea  :  2500
# HOT green_tea  :  2500
# HOT choco_latte  :  3000
# 합계 금액 : 16000
# |                               |
# |                               |
# |                               |
# |                               |
# |                               |
# ⟝------------------------------⟞

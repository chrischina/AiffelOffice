# %%
import torch

tensor = torch.rand(1, 2)
print(tensor)
print(tensor.shape)
# Out:
# tensor([[0.9226, 0.6425]])
# torch.Size([1, 2])

# %%
tensor = tensor.reshape(2, 1)
print(tensor)
print(tensor.shape)
# Out:
# tensor([[0.9226],
#         [0.6425]])
# torch.Size([2, 1])

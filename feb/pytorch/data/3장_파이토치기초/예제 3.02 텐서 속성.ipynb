# %%
import torch


tensor = torch.rand(1, 2)
print(tensor)
print(tensor.shape)
print(tensor.dtype)
print(tensor.device)
# Out:
# tensor([[0.3650, 0.7597]])
# torch.Size([1, 2])
# torch.float32
# cpu
